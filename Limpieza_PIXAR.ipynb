# %%
#Instalación de Librerias
import pandas as pd
import numpy as np
import math
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
# ------------------------------------------------------------------------------
import scipy.stats as stats
from scipy.stats import mannwhitneyu
from scipy.stats import spearmanr
import scipy.stats as stats
from scipy import stats
from scipy.stats import shapiro, poisson, chisquare, expon, kstest, t, levene, bartlett, chi2_contingency
from scipy.stats import ks_2samp
from scipy.stats import bartlett
# -----------------------------------------------------------------------

# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) 
import warnings

# %%
# Función para leer csv
def ejecutar_csv(ruta_csv):
    df= pd.read_csv(ruta_csv)
   
    return df

# %%
# LLamo la función para leer csv e imprimir las 5 primeras filas 
df_oscar = pd.read_csv('Oscars_Best_Animated_Film_Winners_PIXAR.csv', encoding='latin1', index_col=0)
df_oscar.sample(2)
# Out:
#                                          Best Animated Film Country   Studio  \
# Award Year
# 2014                                                 Frozen     USA   Disney
# 2006        Wallace and Gromit: The Curse of the Wererabbit      UK  Aardman
#
#                 Director Director Gender Animation Style           Budget  \
# Award Year
# 2014        Jennifer Lee          Female              3D  £150,000,000.00
# 2006           Nick Park            Male      Stopmotion   £30,000,000.00
#
#                    Box Office             Profit Percentage difference  \
# Award Year
# 2014        £1,280,000,000.00  £1,130,000,000.00               753.33%
# 2006          £192,600,000.00    £162,600,000.00               542.00%
#
#             IMDb Score  Films
# Award Year
# 2014               7.4      1
# 2006               7.5      1

# %%
# LLamo la función para leer csv e imprimir las 5 primeras filas 
df_movies_url = ejecutar_csv('Movies_PIXAR.csv')
df_movies_url.head(1)
# Out:
#                                 movieId   movieTitle  movieYear  \
# 0  6bacd7ec-76c9-3f40-b69a-cde708c3ac01  Toy Story 2       1999
#
#                                        movieURL  movieRank critic_score  \
# 0  https://www.rottentomatoes.com/m/toy_story_2          1         100%
#
#   audience_score
# 0            87%

# %%
# LLamo la función para leer csv e imprimir las 5 primeras filas 
df_pixar_studio = ejecutar_csv('Pixar__Studio12.csv')
df_pixar_studio.sample(2)
# Out:
#       Moviename  Releaseyear  Budget(million)  US and canada(million)  \
# 2   Toy Story 2         1999              900                    2459
# 12        Brave         2012             1850                    2373
#
#     Other territories(million)  Worldwide(million) Rotten Tomatoes
# 2                         2515                4974            100%
# 12                        3017                5390             78%

# %%
# LLamo la función para leer csv e imprimir las 5 primeras filas 
df_pixar_movies = ejecutar_csv('Pixar_Movies.csv')
df_pixar_movies.sample(2)
# Out:
#     Year Released         Movie  Length( in minutes)  RT Score  IMDb Score  \
# 14           2015    Inside Out                  102        98         8.1
# 16           2016  Finding Dory                   97        94         7.2
#
#     Metacritic Score  Opening Weekend (in millions)  \
# 14                94                           90.4
# 16                77                          135.0
#
#     Worldwide Gross (in millions)  Domestic Gross   International Gross  \
# 14                          850.6            356.5                494.1
# 16                         1025.0            486.3                538.7
#
#     Domestic %  International %  Production Budget  Academy Nominated  \
# 14        0.42             0.58              175.0                  1
# 16        0.47             0.53              200.0                  0
#
#     Academy Won                     Director(s)
# 14            1  Pete Docter, Ronnie del Carmen
# 16            0   Andrew Stanton, Angus Maclane

# %%
# Utilizamos una función básica de exploración que hemos creado previamente

def exploracion_dataframe (dataframe):
    """
    Realiza un análisis exploratorio básico de un DataFrame, mostrando información sobre duplicados,
    valores nulos, tipos de datos, valores únicos para columnas categóricas y estadísticas descriptivas
    para columnas categóricas y numéricas, agrupadas por la columna de control.

    Parámetros:
    - dataframe (DataFrame): El DataFrame que se va a explorar.

    Returns: 
    No devuelve nada directamente, pero imprime en la consola la información exploratoria.
    """
    
    print(f"Número de filas: {dataframe.shape[0]}. Número de columnas: {dataframe.shape[1]}")
    print("\n ..................... \n")

    print(f"Número de duplicados: {dataframe.duplicated().sum()}")
    print("\n ..................... \n")
    
    print("Porcentaje de nulos:")
    df_nulos = pd.DataFrame(dataframe.isnull().sum() / dataframe.shape[0] * 100, columns = ["%_nulos"])
    display(df_nulos[df_nulos["%_nulos"] > 0])
    
    print("\n ..................... \n")
    print(f"Tipos de columnas:")
    display(pd.DataFrame(dataframe.dtypes, columns = ["tipo_dato"]))
    
    print("\n ..................... \n")
    print("Valores de las columnas categóricas: ")
    dataframe_categoricas = dataframe.select_dtypes(include = "O")
    
    for col in dataframe_categoricas.columns:
        print(f"La columna {col.upper()} tiene las siguientes valores únicos:")
        display(pd.DataFrame(dataframe[col].value_counts()))    
    
    print("\n ..................... \n")
    print("Valores de las columnas numéricas: ")
    dataframe_numericas = dataframe.select_dtypes(include='number')
    
    for col in dataframe_numericas.columns:
        print(f"La columna {col.upper()} tiene las siguientes valores únicos:")
        display(pd.DataFrame(dataframe[col].value_counts()))    

    print("\n ..................... \n")
    descripcion = dataframe.describe().T
    print(f"Principales valores estadísticos son:")
    print(descripcion.to_string())

# %%
df_pixar_movies.head()
# Out:
#    Year Released           Movie  Length( in minutes)  RT Score  IMDb Score  \
# 0           1995       Toy Story                   81       100         8.3
# 1           1998    A Bug's Life                   96        92         7.2
# 2           1999     Toy Story 2                   92       100         7.9
# 3           2001  Monsters, Inc.                   90        96         8.1
# 4           2003    Finding Nemo                  104        99         8.2
#
#    Metacritic Score  Opening Weekend (in millions)  \
# 0                96                          29.14
# 1                78                           0.30
# 2                88                           0.30
# 3                79                          62.60
# 4                90                          70.30
#
#    Worldwide Gross (in millions)  Domestic Gross   International Gross  \
# 0                          365.3           192.50               172.80
# 1                          363.1           162.80               200.30
# 2                          511.4           245.90               265.50
# 3                          560.5           290.14               270.36
# 4                          936.1           380.50               555.60
#
#    Domestic %  International %  Production Budget  Academy Nominated  \
# 0        0.53             0.47               30.0                  3
# 1        0.45             0.55               45.0                  1
# 2        0.48             0.52               90.0                  1
# 3        0.52             0.48              115.0                  3
# 4        0.41             0.59               94.0                  4
#
#    Academy Won                                Director(s)
# 0            0                              John Lasseter
# 1            0              John Lasseter, Andrew Stanton
# 2            0    John Lasseter, Ash Brannon, Lee Unkrich
# 3            1  Pete Docter, David Silverman, Lee Unkrich
# 4            1                Andrew Stanton, Lee Unkrich

# %%
exploracion_dataframe(df_pixar_movies)

# %%
exploracion_dataframe(df_pixar_studio)

# %%
exploracion_dataframe(df_movies_url)

# %%
def renombrar_columnas_con_guion_bajo(df):
    df.columns = [col.replace(" ", "_") for col in df.columns]
    return df

# %%
# Renombramos columnas con guion bajo
renombrar_columnas_con_guion_bajo(df_pixar_movies)
# Out:
#     Year_Released                Movie  Length(_in_minutes)  RT_Score  \
# 0            1995            Toy Story                   81       100
# 1            1998         A Bug's Life                   96        92
# 2            1999          Toy Story 2                   92       100
# 3            2001       Monsters, Inc.                   90        96
# 4            2003         Finding Nemo                  104        99
# 5            2004      The Incredibles                  115        97
# 6            2006                 Cars                  116        75
# 7            2007          Ratatouille                  111        96
# 8            2008               WALL-E                   97        96
# 9            2009                   Up                   96        98
# 10           2010          Toy Story 3                  103        99
# 11           2011               Cars 2                  113        39
# 12           2012                Brave                  100        79
# 13           2013  Monsters University                  107        80
# 14           2015           Inside Out                  102        98
# 15           2015    The Good Dinosaur                   93        75
# 16           2016         Finding Dory                   97        94
# 17           2017               Cars 3                  102        69
# 18           2017                 Coco                  105        97
# 19           2018       Increadibles 2                  118        93
# 20           2019          Toy Story 4                  100        97
#
#     IMDb_Score  Metacritic_Score  Opening_Weekend_(in_millions)  \
# 0          8.3                96                          29.14
# 1          7.2                78                           0.30
# 2          7.9                88                           0.30
# 3          8.1                79                          62.60
# 4          8.2                90                          70.30
# 5          8.0                90                          70.50
# 6          7.2                73                          60.10
# 7          8.1                96                          47.00
# 8          8.4                95                          63.10
# 9          8.3                88                          68.10
# 10         8.4                92                         110.30
# 11         6.2                57                          66.30
# 12         7.1                69                          66.30
# 13         7.2                65                          82.40
# 14         8.1                94                          90.40
# 15         6.7                66                          39.20
# 16         7.2                77                         135.00
# 17         6.7                59                          53.70
# 18         8.4                81                          50.10
# 19         7.5                80                         182.70
# 20         7.7                84                         121.00
#
#     Worldwide_Gross_(in_millions)  Domestic_Gross_  International_Gross  \
# 0                           365.3           192.50               172.80
# 1                           363.1           162.80               200.30
# 2                           511.4           245.90               265.50
# 3                           560.5           290.14               270.36
# 4                           936.1           380.50               555.60
# 5                           631.4           261.40               370.00
# 6                           462.0           244.10               217.90
# 7                           626.6           206.40               420.20
# 8                           532.5           223.80               308.70
# 9                           731.3           293.00               438.30
# 10                         1068.9            30.70              1038.20
# 11                          560.2           415.00               145.20
# 12                          554.6           191.50               363.10
# 13                          743.6           268.50               475.10
# 14                          850.6           356.50               494.10
# 15                          333.8           123.00               210.80
# 16                         1025.0           486.30               538.70
# 17                          383.5           152.90               230.60
# 18                          796.5           210.50               586.00
# 19                         1242.8           608.60               634.20
# 20                         1072.8           434.00               638.80
#
#     Domestic_%  International_%  Production_Budget  Academy_Nominated  \
# 0         0.53             0.47               30.0                  3
# 1         0.45             0.55               45.0                  1
# 2         0.48             0.52               90.0                  1
# 3         0.52             0.48              115.0                  3
# 4         0.41             0.59               94.0                  4
# 5         0.41             0.59               92.0                  4
# 6         0.53             0.47               70.0                  2
# 7         0.33             0.67              150.0                  5
# 8         0.42             0.58              180.0                  6
# 9         0.40             0.60              175.0                  5
# 10        0.03             0.97              200.0                  5
# 11        0.74             0.26              200.0                  0
# 12        0.35             0.65              185.0                  1
# 13        0.36             0.64              200.0                  0
# 14        0.42             0.58              175.0                  1
# 15        0.37             0.63              187.5                  0
# 16        0.47             0.53              200.0                  0
# 17        0.40             0.60              175.0                  0
# 18        0.26             0.74              175.0                  0
# 19        0.49             0.51              200.0                  1
# 20        0.40             0.60              200.0                  1
#
#     Academy_Won                                  Director(s)
# 0             0                                John Lasseter
# 1             0                John Lasseter, Andrew Stanton
# 2             0      John Lasseter, Ash Brannon, Lee Unkrich
# 3             1    Pete Docter, David Silverman, Lee Unkrich
# 4             1                  Andrew Stanton, Lee Unkrich
# 5             2                                    Brad Bird
# 6             0                     John Lasseter, Joe Ranft
# 7             1                       Bard Bird, Jan Pinkava
# 8             1                               Andrew Stanton
# 9             2                    Pete Docter, Bob Peterson
# 10            2                                  Lee Unkrich
# 11            0                    John Lasseter, Brad Lewis
# 12            1  Mark Andrews, Brenda Chapman, Steve Purcell
# 13            0                                  Dan Scanlon
# 14            1               Pete Docter, Ronnie del Carmen
# 15            0                                   Peter Sohn
# 16            0                Andrew Stanton, Angus Maclane
# 17            0                                    Brian Fee
# 18            2                   Lee Unkrich, Adrian Molina
# 19            0                                    Brad Bird
# 20            1                                  Josh Cooley

# %%
df_pixar_movies.to_csv('Pixar_Movies_Clean.csv')

# %%
df_movies_url.to_csv('Pixar_URLs.csv')
